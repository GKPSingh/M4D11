# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4,5]);

# %%
x = [1,2,3,4,5]
y= [11,12,13,14,15]
plt.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
fig, ax = plt.subplots(figsize = (10,10))
ax.plot(x,y);

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(x,y);
ax.set(title = 'Simple Plot', xlabel = 'x-axis', ylabel = 'y-axis');

# %%
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y = x**2
fig, ax = plt.subplots(figsize = (10,8))
ax.plot(x, y)
ax.set(title = 'Graph', ylabel = 'y = x^^2', xlabel = 'x');

# %% [markdown]
# ## Scatter Plot

# %%
y = np.exp(x)
fig, ax = plt.subplots(figsize = (10,8))
ax.scatter(x,y)
ax.set(Title = 'Graph', ylabel = 'y = exp(x)', xlabel = 'x');
# Out:
# <ipython-input-9-be03ddcfd2d7>:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Graph', ylabel = 'y = exp(x)', xlabel = 'x');

# %%
# Another Scatter plot
fig, ax = plt.subplots(figsize = (10,8))
ax.scatter(x, np.sin(x))
ax.set(Title = 'Amazing Sine Wave', ylabel = 'y = sin(x)', xlabel = 'x');
# Out:
# <ipython-input-10-1916db6b00d7>:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Amazing Sine Wave', ylabel = 'y = sin(x)', xlabel = 'x');

# %%
# make a plot from dictionary
nut_butter_prices = {'Almond Butter':10, 'Peanut Butter':15, 'Cashew Butter':12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(Title = 'Gurkirpal Butter Shop', xlabel = 'Type of Butter', ylabel = 'Price of Butter ($)');
# Out:
# <ipython-input-11-832306be99e7>:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Gurkirpal Butter Shop', xlabel = 'Type of Butter', ylabel = 'Price of Butter ($)');

# %%
nut_butter_prices = {'Almond Butter':10, 'Peanut Butter':15, 'Cashew Butter':12}
fig, ax = plt.subplots(figsize = (10, 8))
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));
ax.set(Title = 'Gurkirpal Butter Shop', ylabel = 'Type of Butter', xlabel = 'Price of Butter ($)');
# Out:
# <ipython-input-12-5c6eb30f67a5>:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Gurkirpal Butter Shop', ylabel = 'Type of Butter', xlabel = 'Price of Butter ($)');

# %%
## Making Histogram
x  = np.random.randn(1000)
fig,ax =plt.subplots()
ax.hist(x);
ax.set(Title = 'HISTOGRAM', ylabel = 'Frequency', xlabel = 'Values');
# Out:
# <ipython-input-13-76bd52ee61ce>:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'HISTOGRAM', ylabel = 'Frequency', xlabel = 'Values');

# %% [markdown]
# ## Making Subplots

# %%
fig, ((ax1, ax2), (ax3, ax4))= plt.subplots(nrows = 2, ncols=2, figsize = (10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.randn(10),np.random.randn(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %% [markdown]
# ### Other way to plot subplots

# %%
fig, ax = plt.subplots(nrows = 2, ncols =2, figsize = (10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.randn(10),np.random.randn(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas DataFrame

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\, \.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales['Price'] = car_sales['Price'].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Sale Date'] = pd.date_range('1/1/2021', periods = len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2021-01-01
# 1   Honda    Red          87899      4   5000 2021-01-02
# 2  Toyota   Blue          32549      3   7000 2021-01-03
# 3     BMW  Black          11179      5  22000 2021-01-04
# 4  Nissan  White         213095      4   3500 2021-01-05
# 5  Toyota  Green          99213      4   4500 2021-01-06
# 6   Honda   Blue          45698      4   7500 2021-01-07
# 7   Honda   Blue          54738      4   7000 2021-01-08
# 8  Toyota  White          60000      4   6250 2021-01-09
# 9  Nissan  White          31600      4   9700 2021-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %% [markdown]
# car_sales.plot('Sale Date', 'Total Sales');

# %%
car_sales['Price'] = car_sales['Price'].astype(int) 
car_sales.plot('Odometer (KM)', 'Price', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# ## Make a Bar Graph

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2021-01-01         4000
# 1   Honda    Red          87899      4   5000 2021-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2021-01-03        16000
# 3     BMW  Black          11179      5  22000 2021-01-04        38000
# 4  Nissan  White         213095      4   3500 2021-01-05        41500
# 5  Toyota  Green          99213      4   4500 2021-01-06        46000
# 6   Honda   Blue          45698      4   7500 2021-01-07        53500
# 7   Honda   Blue          54738      4   7000 2021-01-08        60500
# 8  Toyota  White          60000      4   6250 2021-01-09        66750
# 9  Nissan  White          31600      4   9700 2021-01-10        76450

# %%
car_sales.plot(y = 'Odometer (KM)', x = 'Make', kind  = 'bar' );

# %% [markdown]
# ### Histogram

# %%
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
car_sales['Odometer (KM)'].plot.hist(bins = 10);

# %%
heart_disease = pd.read_csv('heart-disease.csv')

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
len(heart_disease)
# Out:
# 303

# %%
heart_disease.shape
# Out:
# (303, 14)

# %%
heart_disease['age'].plot.hist(bins = 120);

# %%
heart_disease['age'].plot(kind='hist', bins = 120);

# %%
heart_disease.plot.hist(figsize =(10,30), subplots = True);

# %%
over_50 = heart_disease[heart_disease['age']>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over_50)
# Out:
# 208

# %%
# Pyplot Method
over_50.plot(kind = 'scatter', x= 'age', y = 'chol', c='target');

# %%
fig, ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = 'scatter', y ='chol', x = 'age', c= 'target', ax =ax);

# %%
## OO method mixed with pyplot method
fig, ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = 'scatter', y ='chol', x = 'age', c= 'target', ax =ax);
ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
## OO method from scratch
fig, ax = plt.subplots(figsize = (10, 6))
scatter = ax.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target'])

# %%
fig, ax = plt.subplots(figsize = (10, 6))
scatter = ax.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target'])
ax.set(Title = 'Heart Disease and Cholestrol Level', xlabel = 'Age', ylabel = 'Cholestrol');
# Out:
# <ipython-input-42-70b4d4a5cfd6>:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Heart Disease and Cholestrol Level', xlabel = 'Age', ylabel = 'Cholestrol');

# %%
fig, ax = plt.subplots(figsize = (10, 6))
scatter = ax.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target'])
ax.set(Title = 'Heart Disease and Cholestrol Level', xlabel = 'Age', ylabel = 'Cholestrol');
ax.legend(*scatter.legend_elements(), title = 'Target');
# Out:
# <ipython-input-43-3488f12a5618>:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Heart Disease and Cholestrol Level', xlabel = 'Age', ylabel = 'Cholestrol');

# %%
# Customize the plot
fig, ax = plt.subplots(figsize = (10, 6))
scatter = ax.scatter(x = over_50['age'],
                     y = over_50['chol'],
                     c = over_50['target'])
ax.set(Title = 'Heart Disease and Cholestrol Level', xlabel = 'Age', ylabel = 'Cholestrol');
# Add a legend
ax.legend(*scatter.legend_elements(), title = 'Target');
# Add a horizontal line
ax.axhline(over_50['chol'].mean(),linestyle ='--' );
# Out:
# <ipython-input-44-44716af5a84d>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax.set(Title = 'Heart Disease and Cholestrol Level', xlabel = 'Age', ylabel = 'Cholestrol');

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chal, thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols =1, figsize = (10,10))
# Add data tp ax0
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'])
# Customize ax0
ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# Add a legend
ax0.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax0.axhline(y=over_50['chol'].mean(), linestyle='--' );



# Add data tp ax0
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'])
# Customize ax0
ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')
# Add a legend
ax1.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax1.axhline(y=over_50['thalach'].mean(), linestyle='--' );
# Out:
# <ipython-input-46-2c0759544906>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# <ipython-input-46-2c0759544906>:17: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')

# %%
# Subplot of chal, thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols =1, figsize = (10,10))
# Add data tp ax0
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'])
# Customize ax0
ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# Add a legend
ax0.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax0.axhline(y=over_50['chol'].mean(), linestyle='--' );



# Add data tp ax0
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'])
# Customize ax0
ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')
# Add a legend
ax1.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax1.axhline(y=over_50['thalach'].mean(), linestyle='--' );

# Add atitle to the figure
fig.suptitle('Heart_Disease Analyisis', fontsize =16, fontweight = 'bold');
# Out:
# <ipython-input-47-3a75fefd77ff>:6: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# <ipython-input-47-3a75fefd77ff>:17: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')

# %%
# Customizing Matplotlib plots and getting stylish
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use( 'seaborn-notebook')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales['Price'].plot();

# %%
car_sales.plot(x = 'Odometer (KM)', y = 'Price', kind = 'scatter');

# %%
plt.style.use('ggplot')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-whitegrid')
# Subplot of chal, thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols =1, figsize = (10,10))
# Add data tp ax0
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'], cmap= 'winter')
# Customize ax0
ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# Add a legend
ax0.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax0.axhline(y=over_50['chol'].mean(), linestyle='--' );



# Add data tp ax0
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'], cmap ='plasma')
# Customize ax0
ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')
# Add a legend
ax1.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax1.axhline(y=over_50['thalach'].mean(), linestyle='--' );

# Add atitle to the figure
fig.suptitle('Heart_Disease Analyisis', fontsize =16, fontweight = 'bold');
# Out:
# <ipython-input-57-6dc1852e8e5f>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# <ipython-input-57-6dc1852e8e5f>:18: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')

# %%
plt.style.use('seaborn-whitegrid')
# Subplot of chal, thalach
fig,(ax0, ax1) = plt.subplots(nrows = 2, ncols =1, figsize = (10,10))
# Add data tp ax0
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c= over_50['target'], cmap= 'winter')
# Customize ax0
ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')

ax0.set_xlim([50,80])

# Add a legend
ax0.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax0.axhline(y=over_50['chol'].mean(), linestyle='--' );



# Add data tp ax0
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c= over_50['target'], cmap ='winter')
# Customize ax0
ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')

ax1.set_xlim([50,80])

# Add a legend
ax1.legend(*scatter.legend_elements(), title = 'Target')
# Add a meanline
ax1.axhline(y=over_50['thalach'].mean(), linestyle='--' );

# Add atitle to the figure
fig.suptitle('Heart_Disease Analyisis', fontsize =16, fontweight = 'bold');
# Out:
# <ipython-input-58-88d35791f431>:7: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax0.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Cholestrol')
# <ipython-input-58-88d35791f431>:21: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   ax1.set(Title = 'Heart Disease and Cholestrol Levels', xlabel = 'Age', ylabel = 'Thalach')
