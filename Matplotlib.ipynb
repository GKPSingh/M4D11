# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3,4,5]);

# %%
x = [1,2,3,4,5]
y= [11,12,13,14,15]
plt.plot(x,y)

# %%
fig, ax = plt.subplots()
ax.plot(x,y);
